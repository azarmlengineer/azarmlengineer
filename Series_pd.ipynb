# %% [markdown]
# <a href="https://colab.research.google.com/github/azarmlengineer/azarmlengineer/blob/main/Series_pd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dummy_vector = pd.Series([1,None,2,None,3])

# %%
dummy_vector.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# dtype: bool

# %%
my_data = [10,20,30]

# %%
pd.Series(my_data, index = [1,2,3])
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %%
ser1 = pd.Series([1,2,3,4],['ca','ur','co','az'])
ser2 = pd.Series([1,2,5,4],['ca','or','nv','az'])

# %%
ser1
# Out:
# ca    1
# ur    2
# co    3
# az    4
# dtype: int64

# %%
ser2
# Out:
# ca    1
# or    2
# nv    5
# az    4
# dtype: int64

# %%
ser1[0]
# Out:
# 1

# %%
ser1[1:4]
# Out:
# ur    2
# co    3
# az    4
# dtype: int64

# %%
ser1 = pd.Series([1,2,3,4])
ser2 = pd.Series([1,2,3,4])

# %%
ser3 = ser1+ser2
ser3
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# dtype: int64

# %%
ser1 = pd.Series([1,2,3,4,8])
ser2 = pd.Series([1,2,3,4])

# %%
ser3 = ser1+ser2
ser3
# Out:
# 0    2.0
# 1    4.0
# 2    6.0
# 3    8.0
# 4    NaN
# dtype: float64

# %%
ser4 = ser1*ser2
ser4
# Out:
# 0     1.0
# 1     4.0
# 2     9.0
# 3    16.0
# 4     NaN
# dtype: float64

# %%
ser1 = pd.Series([1,2,3,4],['ca','or','co','az'])
ser2 = pd.Series([1,2,5,4],['ca','or','nv','az'])
ser1+ser2
# Out:
# az    8.0
# ca    2.0
# co    NaN
# nv    NaN
# or    4.0
# dtype: float64

# %%
from numpy.random import randn as rn
np.random.seed(101)
matrix_data =rn(5,4)
row_labels = ['A','B','C','D','E']
coloumn_headings = ['W','X','Y','Z']

df = pd.DataFrame(data=matrix_data,index=row_labels,columns=coloumn_headings)
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['X']
# Out:
# A    0.628133
# B   -0.319318
# C    0.740122
# D   -0.758872
# E    1.978757
# Name: X, dtype: float64

# %%
df[['X','Y']] #getting multiple coloumns
# Out:
#           X         Y
# A  0.628133  0.907969
# B -0.319318 -0.848077
# C  0.740122  0.528813
# D -0.758872 -0.933237
# E  1.978757  2.605967

# %%
df['NEW']= df['X']+df['Y']

# %%
df
# Out:
#           W         X         Y         Z       NEW
# A  2.706850  0.628133  0.907969  0.503826  1.536102
# B  0.651118 -0.319318 -0.848077  0.605965 -1.167395
# C -2.018168  0.740122  0.528813 -0.589001  1.268936
# D  0.188695 -0.758872 -0.933237  0.955057 -1.692109
# E  0.190794  1.978757  2.605967  0.683509  4.584725

# %%
df.drop('NEW')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-463ec57aed7c> in <cell line: 1>()
# ----> 1 df.drop('NEW')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
df.drop('NEW',axis=1)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#           W         X         Y         Z       NEW
# A  2.706850  0.628133  0.907969  0.503826  1.536102
# B  0.651118 -0.319318 -0.848077  0.605965 -1.167395
# C -2.018168  0.740122  0.528813 -0.589001  1.268936
# D  0.188695 -0.758872 -0.933237  0.955057 -1.692109
# E  0.190794  1.978757  2.605967  0.683509  4.584725

# %%
df.drop('NEW',axis=1,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.loc['D']
# Out:
# W    0.188695
# X   -0.758872
# Y   -0.933237
# Z    0.955057
# Name: D, dtype: float64

# %%
df.iloc['A']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-3cf21a555a1f> in <cell line: 1>()
# ----> 1 df.iloc['A']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1620             key = item_from_zerodim(key)
#    1621             if not is_integer(key):
# -> 1622                 raise TypeError("Cannot index by location index with a non-integer key")
#    1623
#    1624             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key

# %%
df.iloc[0]
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
df.ix['X']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-f271e3519ffe> in <cell line: 1>()
# ----> 1 df.ix['X']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
df.iloc[[1,2]]
# Out:
#           W         X         Y         Z
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001

# %%
df.loc['B','W']
# Out:
# 0.6511179479432686

# %%
df.loc[['B','C'],['Y','Z']]
# Out:
#           Y         Z
# B -0.848077  0.605965
# C  0.528813 -0.589001

# %%
df>0
# Out:
#        W      X      Y      Z
# A   True   True   True   True
# B   True  False  False   True
# C  False   True   True  False
# D   True  False  False   True
# E   True   True   True   True

# %%
df.loc[['A','B','C']]>0
# Out:
#        W      X      Y      Z
# A   True   True   True   True
# B   True  False  False   True
# C  False   True   True  False

# %%
df[df>0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
matrix_data = np.matrix('22,64,140;42,70,148;30,62,125;35,68,160;25,62,152')
row_labels = ['A','B','C','D','E']
column_headings = ['Age','Height','Weight']
df=pd.DataFrame(data=matrix_data,index=row_labels,columns=column_headings)

# %%
df
# Out:
#    Age  Height  Weight
# A   22      64     140
# B   42      70     148
# C   30      62     125
# D   35      68     160
# E   25      62     152

# %%
df[df>65]
# Out:
#    Age  Height  Weight
# A  NaN     NaN     140
# B  NaN    70.0     148
# C  NaN     NaN     125
# D  NaN    68.0     160
# E  NaN     NaN     152

# %%
booldf1 = df['Height']>65
booldf2 = df['Weight']>145

# %%
booldf1
# Out:
# A    False
# B     True
# C    False
# D     True
# E    False
# Name: Height, dtype: bool

# %%
df[(booldf1) &(booldf2)]
# Out:
#    Age  Height  Weight
# B   42      70     148
# D   35      68     160

# %%
df
# Out:
#    Age  Height  Weight
# A   22      64     140
# B   42      70     148
# C   30      62     125
# D   35      68     160
# E   25      62     152

# %%
df.reset_index()
# Out:
#   index  Age  Height  Weight
# 0     A   22      64     140
# 1     B   42      70     148
# 2     C   30      62     125
# 3     D   35      68     160
# 4     E   25      62     152

# %%
df.reset_index(drop=True)
# Out:
#    Age  Height  Weight
# 0   22      64     140
# 1   42      70     148
# 2   30      62     125
# 3   35      68     160
# 4   25      62     152

# %%
df['Profession']='Student Teacher Engineer Doctor nurse'.split()
df
# Out:
#    Age  Height  Weight Profession
# A   22      64     140    Student
# B   42      70     148    Teacher
# C   30      62     125   Engineer
# D   35      68     160     Doctor
# E   25      62     152      nurse

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc['A']
# Out:
# Age                22
# Height             64
# Weight            140
# Profession    Student
# Name: A, dtype: object

# %%
type(df.loc['A'])
# Out:
# pandas.core.series.Series

# %%
df['Age']
# Out:
# A    22
# B    42
# C    30
# D    35
# E    25
# Name: Age, dtype: int64

# %%
type[df['Age']]
# Out:
# type[A    22
# B    42
# C    30
# D    35
# E    25
# Name: Age, dtype: int64]

# %%
df
# Out:
#    Age  Height  Weight Profession
# A   22      64     140    Student
# B   42      70     148    Teacher
# C   30      62     125   Engineer
# D   35      68     160     Doctor
# E   25      62     152      nurse

# %%
df.set_index('Profession')
# Out:
#             Age  Height  Weight
# Profession
# Student      22      64     140
# Teacher      42      70     148
# Engineer     30      62     125
# Doctor       35      68     160
# nurse        25      62     152

# %%
#multiindexing
# Index Levels
outside = ['G1','G1','G1','G2','G2','G2']
inside=[1,2,3,1,2,3]

# %%
hier_index= list(zip(outside,inside))

# %%
hier_index
# Out:
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
hier_index=pd.MultiIndex.from_tuples(hier_index)

# %%
hier_index
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
np.random.seed(101)
df1 = pd.DataFrame(data=np.round(rn(6,3),2), index= hier_index, columns=['A','B','C'])

# %%
df1
# Out:
#          A     B     C
# G1 1  2.71  0.63  0.91
#    2  0.50  0.65 -0.32
#    3 -0.85  0.61 -2.02
# G2 1  0.74  0.53 -0.59
#    2  0.19 -0.76 -0.93
#    3  0.96  0.19  1.98

# %%
df1.loc['G2'].loc[[1,3]][["B",'C']]
# Out:
#       B     C
# 1  0.53 -0.59
# 3  0.19  1.98

# %%
df1.loc['G2']
# Out:
#       A     B     C
# 1  0.74  0.53 -0.59
# 2  0.19 -0.76 -0.93
# 3  0.96  0.19  1.98

# %%
df1.loc['G2'].loc[[1,3]][['B','C']]
# Out:
#       B     C
# 1  0.53 -0.59
# 3  0.19  1.98

# %%
df1.index.names=['Outer','Inner']

# %%
df1
# Out:
#                 A     B     C
# Outer Inner
# G1    1      2.71  0.63  0.91
#       2      0.50  0.65 -0.32
#       3     -0.85  0.61 -2.02
# G2    1      0.74  0.53 -0.59
#       2      0.19 -0.76 -0.93
#       3      0.96  0.19  1.98

# %%
#cross section

df1.xs('G1')
# Out:
#           A     B     C
# Inner
# 1      2.71  0.63  0.91
# 2      0.50  0.65 -0.32
# 3     -0.85  0.61 -2.02

# %%
df1.xs(2,level='Inner')
# Out:
#           A     B     C
# Outer
# G1     0.50  0.65 -0.32
# G2     0.19 -0.76 -0.93
