# %% [markdown]
# <a href="https://colab.research.google.com/github/azarmlengineer/azarmlengineer/blob/main/exercise2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
#https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')

# %%
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df.shape
# Out:
# (4656, 12)

# %%
df1 = pd.read_csv("https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv")

# %%
df1.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   STATION       117208 non-null  object
#  1   STATION_NAME  117208 non-null  object
#  2   DATE          117208 non-null  int64
#  3   PRCP          117208 non-null  int64
#  4   SNWD          117208 non-null  int64
#  5   SNOW          117208 non-null  int64
#  6   TMAX          117208 non-null  int64
#  7   TMIN          117208 non-null  int64
#  8   WDFG          117208 non-null  int64
#  9   PGTM          117208 non-null  int64
#  10  WSFG          117208 non-null  int64
#  11  WT09          117208 non-null  int64
#  12  WT07          117208 non-null  int64
#  13  WT01          117208 non-null  int64
#  14  WT06          117208 non-null  int64
#  15  WT05          117208 non-null  int64
#  16  WT04          117208 non-null  int64
#  17  WT16          117208 non-null  int64
# ...

# %%
#get the row names
df.index
# Out:
# RangeIndex(start=0, stop=4656, step=1)

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655])

# %%
df.columns
# Out:
# Index(['Indicator', 'PUBLISH STATES', 'Year', 'WHO region',
#        'World Bank income group', 'Country', 'Sex', 'Display Value', 'Numeric',
#        'Low', 'High', 'Comments'],
#       dtype='object')

# %%
df1.index.values
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207])

# %%
df1.columns
# Out:
# Index(['STATION', 'STATION_NAME', 'DATE', 'PRCP', 'SNWD', 'SNOW', 'TMAX',
#        'TMIN', 'WDFG', 'PGTM', 'WSFG', 'WT09', 'WT07', 'WT01', 'WT06', 'WT05',
#        'WT04', 'WT16', 'WT08', 'WT18', 'WT03'],
#       dtype='object')

# %%
df.columns.values
# Out:
# array(['Indicator', 'PUBLISH STATES', 'Year', 'WHO region',
#        'World Bank income group', 'Country', 'Sex', 'Display Value',
#        'Numeric', 'Low', 'High', 'Comments'], dtype=object)

# %%
df.rename(columns={'Indicator':'Indicator_id'},inplace=True)

# %%
df.head(2)
# Out:
#                        Indicator_id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df.rename(columns={'PUBLISH STATES':'Pulications STATES','WHO region':'WHO Region'},inplace=True)

# %%
df.head(2)
# Out:
#                        Indicator_id Pulications STATES  Year WHO Region  \
# 0  Life expectancy at birth (years)          Published  1990     Europe
# 1  Life expectancy at birth (years)          Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df.sort_values('Year',ascending=True).head(2)
# Out:
#                           Indicator_id Pulications STATES  Year WHO Region  \
# 0     Life expectancy at birth (years)          Published  1990     Europe
# 1270  Life expectancy at birth (years)          Published  1990     Europe
#
#      World Bank income group  Country         Sex  Display Value  Numeric  \
# 0                High-income  Andorra  Both sexes             77     77.0
# 1270             High-income  Germany        Male             72     72.0
#
#       Low  High  Comments
# 0     NaN   NaN       NaN
# 1270  NaN   NaN       NaN

# %%
df.sort_values(['Year','Numeric'],ascending=True).head(5)
# Out:
#                            Indicator_id Pulications STATES  Year WHO Region  \
# 1474  Life expectancy at age 60 (years)          Published  1990     Africa
# 1476  Life expectancy at age 60 (years)          Published  1990     Africa
# 1813  Life expectancy at age 60 (years)          Published  1990     Africa
# 3071  Life expectancy at age 60 (years)          Published  1990     Africa
# 577   Life expectancy at age 60 (years)          Published  1990     Africa
#
#      World Bank income group       Country         Sex  Display Value  \
# 1474              Low-income  Sierra Leone        Male             11
# 1476              Low-income  Sierra Leone      Female             11
# 1813              Low-income       Eritrea        Male             11
# 3071              Low-income  Sierra Leone  Both sexes             11
# 577               Low-income       Eritrea  Both sexes             12
#
#       Numeric  Low  High  Comments
# 1474     11.0  NaN   NaN       NaN
# ...

# %%
df[['Indicator_id','Pulications STATES','Year']].head(2)
# Out:
#                        Indicator_id Pulications STATES  Year
# 0  Life expectancy at birth (years)          Published  1990
# 1  Life expectancy at birth (years)          Published  2000

# %%
df[pd.unique(['Country']+df.columns.values.tolist()).tolist()].head(5)
# Out:
#                 Country                       Indicator_id Pulications STATES  \
# 0               Andorra   Life expectancy at birth (years)          Published
# 1               Andorra   Life expectancy at birth (years)          Published
# 2               Andorra  Life expectancy at age 60 (years)          Published
# 3               Andorra  Life expectancy at age 60 (years)          Published
# 4  United Arab Emirates   Life expectancy at birth (years)          Published
#
#    Year             WHO Region World Bank income group         Sex  \
# 0  1990                 Europe             High-income  Both sexes
# 1  2000                 Europe             High-income  Both sexes
# 2  2012                 Europe             High-income      Female
# 3  2000                 Europe             High-income  Both sexes
# 4  2012  Eastern Mediterranean             High-income      Female
#
#    Display Value  Numeric  Low  High  Comments
# ...

# %%
df.columns.values.tolist() #list all the columns
# Out:
# ['Indicator_id',
#  'Pulications STATES',
#  'Year',
#  'WHO Region',
#  'World Bank income group',
#  'Country',
#  'Sex',
#  'Display Value',
#  'Numeric',
#  'Low',
#  'High',
#  'Comments']

# %%
['Country']+df.columns.values.tolist() #adding country to the list
# Out:
# ['Country',
#  'Indicator_id',
#  'Pulications STATES',
#  'Year',
#  'WHO Region',
#  'World Bank income group',
#  'Country',
#  'Sex',
#  'Display Value',
#  'Numeric',
#  'Low',
#  'High',
#  'Comments']

# %%
pd.unique(['Country']+df.columns.values.tolist()) # taking unique value then Country is duplicate so that is unique
# Out:
# array(['Country', 'Indicator_id', 'Pulications STATES', 'Year',
#        'WHO Region', 'World Bank income group', 'Sex', 'Display Value',
#        'Numeric', 'Low', 'High', 'Comments'], dtype=object)

# %%
pd.unique(['Country']+df.columns.values.tolist()).tolist() # again all converting all this to list
# Out:
# ['Country',
#  'Indicator_id',
#  'Pulications STATES',
#  'Year',
#  'WHO Region',
#  'World Bank income group',
#  'Sex',
#  'Display Value',
#  'Numeric',
#  'Low',
#  'High',
#  'Comments']

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.Country.values
# Out:
# array(['Andorra', 'Andorra', 'Andorra', ..., 'South Africa', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
col='WHO Region'
df[[col]].values[:,0]
# Out:
# array(['Europe', 'Europe', 'Europe', ..., 'Africa', 'Africa', 'Africa'],
#       dtype=object)

# %%
df.iloc[[11,24,37]]
# Out:
#                          Indicator_id Pulications STATES  Year  \
# 11   Life expectancy at birth (years)          Published  2012
# 24  Life expectancy at age 60 (years)          Published  2012
# 37  Life expectancy at age 60 (years)          Published  2012
#
#          WHO Region World Bank income group            Country     Sex  \
# 11           Europe             High-income            Austria  Female
# 24  Western Pacific             High-income  Brunei Darussalam  Female
# 37           Europe             High-income             Cyprus  Female
#
#     Display Value  Numeric  Low  High  Comments
# 11             83     83.0  NaN   NaN       NaN
# 24             21     21.0  NaN   NaN       NaN
# 37             26     26.0  NaN   NaN       NaN

# %%
df.drop([12,23,56],axis=0).head(5)
# Out:
#                         Indicator_id Pulications STATES  Year  \
# 0   Life expectancy at birth (years)          Published  1990
# 1   Life expectancy at birth (years)          Published  2000
# 2  Life expectancy at age 60 (years)          Published  2012
# 3  Life expectancy at age 60 (years)          Published  2000
# 4   Life expectancy at birth (years)          Published  2012
#
#               WHO Region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# ...

# %%
df[3:].head(5)
# Out:
#                         Indicator_id Pulications STATES  Year  \
# 3  Life expectancy at age 60 (years)          Published  2000
# 4   Life expectancy at birth (years)          Published  2012
# 5   Life expectancy at birth (years)          Published  2000
# 6  Life expectancy at age 60 (years)          Published  1990
# 7  Life expectancy at age 60 (years)          Published  2012
#
#               WHO Region World Bank income group               Country  \
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
# 5               Americas             High-income   Antigua and Barbuda
# 6               Americas             High-income   Antigua and Barbuda
# 7               Americas             High-income   Antigua and Barbuda
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 3  Both sexes             23     23.0  NaN   NaN       NaN
# ...

# %%
df.tail(-3)
# Out:
#                                          Indicator_id Pulications STATES  \
# 3                   Life expectancy at age 60 (years)          Published
# 4                    Life expectancy at birth (years)          Published
# 5                    Life expectancy at birth (years)          Published
# 6                   Life expectancy at age 60 (years)          Published
# 7                   Life expectancy at age 60 (years)          Published
# ...                                               ...                ...
# 4651  Healthy life expectancy (HALE) at birth (years)          Published
# 4652  Healthy life expectancy (HALE) at birth (years)          Published
# 4653  Healthy life expectancy (HALE) at birth (years)          Published
# 4654  Healthy life expectancy (HALE) at birth (years)          Published
# 4655  Healthy life expectancy (HALE) at birth (years)          Published
#
#       Year             WHO Region World Bank income group  \
# ...

# %%
df.tail(3)
# Out:
#                                          Indicator_id Pulications STATES  \
# 4653  Healthy life expectancy (HALE) at birth (years)          Published
# 4654  Healthy life expectancy (HALE) at birth (years)          Published
# 4655  Healthy life expectancy (HALE) at birth (years)          Published
#
#       Year WHO Region World Bank income group       Country         Sex  \
# 4653  2000     Africa     Upper-middle-income  South Africa        Male
# 4654  2000     Africa              Low-income        Zambia  Both sexes
# 4655  2012     Africa              Low-income      Zimbabwe      Female
#
#       Display Value  Numeric  Low  High  Comments
# 4653             49     49.0  NaN   NaN       NaN
# 4654             36     36.0  NaN   NaN       NaN
# 4655             51     51.0  NaN   NaN       NaN

# %%
users = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')
sessions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv')
products = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')
transactions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

# %%
users.head()
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   UserID      5 non-null      int64
#  1   User        5 non-null      object
#  2   Gender      5 non-null      object
#  3   Registered  5 non-null      object
#  4   Cancelled   2 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 328.0+ bytes

# %%
users['Registered'] = pd.to_datetime(users.Registered)
users['Cancelled'] = pd.to_datetime(users.Cancelled)

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   UserID      5 non-null      int64
#  1   User        5 non-null      object
#  2   Gender      5 non-null      object
#  3   Registered  5 non-null      datetime64[ns]
#  4   Cancelled   2 non-null      datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(2)
# memory usage: 328.0+ bytes

# %%
sessions.head()
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4

# %%
products.head()
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# 2          3       C  10.65
# 3          4       D  10.02
# 4          5       E  29.66

# %%
transactions.head()
#transactions.info()
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1

# %%
transactions['TransactionDate'] = pd.to_datetime(transactions.TransactionDate)
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    10 non-null     int64
#  1   TransactionDate  10 non-null     datetime64[ns]
#  2   UserID           9 non-null      float64
#  3   ProductID        10 non-null     int64
#  4   Quantity         10 non-null     int64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 528.0 bytes

# %%
transactions.merge(users, how='left',on='UserID')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender Registered  Cancelled
# 0     NaN        NaT        NaT
# 1  female 2012-10-23 2016-06-07
# 2  female 2012-10-23 2016-06-07
# 3    male 2012-12-21        NaT
# ...

# %%
transactions['UserID']
# Out:
# 0    7.0
# 1    3.0
# 2    3.0
# 3    1.0
# 4    2.0
# 5    2.0
# 6    3.0
# 7    NaN
# 8    7.0
# 9    3.0
# Name: UserID, dtype: float64

# %%
transactions['UserID'].isin(users['UserID'])
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# 8    False
# 9     True
# Name: UserID, dtype: bool

# %%
~transactions['UserID'].isin(users['UserID']) # '~' will convert true to false
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8     True
# 9    False
# Name: UserID, dtype: bool

# %%
transactions[~transactions['UserID'].isin(users['UserID'])]
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3

# %%
transactions.merge(users,how='inner',on='UserID')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              7      2013-12-30     3.0          4         1  Caroline
# 3             10      2016-05-08     3.0          4         4  Caroline
# 4              4      2012-08-26     1.0          2         3   Charles
# 5              5      2013-06-06     2.0          4         1     Pedro
# 6              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender Registered  Cancelled
# 0  female 2012-10-23 2016-06-07
# 1  female 2012-10-23 2016-06-07
# 2  female 2012-10-23 2016-06-07
# 3  female 2012-10-23 2016-06-07
# 4    male 2012-12-21        NaT
# 5    male 2010-08-01 2010-08-08
# 6    male 2010-08-01 2010-08-08

# %%
transactions.merge(users,how='outer',on='UserID')
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1             9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 5            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 6             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 7             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 8             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 9             8.0      2014-04-24     NaN        2.0       3.0       NaN
# 10            NaN             NaT     4.0        NaN       NaN   Brielle
# 11            NaN             NaT     5.0        NaN       NaN  Benjamin
#
# ...

# %%
pd.merge(left=users, right=sessions, how='inner', left_on=['UserID', 'Registered'], right_on=['UserID','SessionDate'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-7766d3d2751b> in <cell line: 1>()
# ----> 1 pd.merge(left=users, right=sessions, how='inner', left_on=['UserID', 'Registered'], right_on=['UserID','SessionDate'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     705         # validate the merge keys dtypes. We may need to coerce
# ...

# %%
sessions['SessionDate']=pd.to_datetime(sessions.SessionDate)

# %%
pd.merge(left=users, right=sessions, how='inner', left_on=['UserID', 'Registered'], right_on=['UserID','SessionDate'])
# Out:
#    UserID     User  Gender Registered  Cancelled  SessionID SessionDate
# 0       2    Pedro    male 2010-08-01 2010-08-08          2  2010-08-01
# 1       4  Brielle  female 2013-07-17        NaT          9  2013-07-17

# %%
df1=pd.DataFrame({'key':np.repeat(1,users.shape[0]),'UserID':users.UserID})
df2=pd.DataFrame({'key':np.repeat(1,products.shape[0]),'ProductID':products.ProductID})
user_products=pd.merge(df1,df2,on='key')[['UserID','ProductID']]

# %%
users.shape
# Out:
# (5, 5)

# %%
users.shape[0]
# Out:
# 5

# %%
np.repeat(1,users.shape[0])
# Out:
# array([1, 1, 1, 1, 1])

# %%
np.repeat(5,users.shape[0])
# Out:
# array([5, 5, 5, 5, 5])

# %%
pd.merge(user_products,transactions, on=['UserID','ProductID']).groupby(['UserID','ProductID']).apply(lambda x:pd.Series(dict(Quantity=x.Quantity.sum()))).reset_index().fillna(0)
# Out:
#    UserID  ProductID  Quantity
# 0       1          2         3
# 1       2          4         1
# 2       2          5         6
# 3       3          3         1
# 4       3          4         6

# %%
pd.merge(user_products,transactions, on=['UserID','ProductID'])
# Out:
#    UserID  ProductID  TransactionID TransactionDate  Quantity
# 0       1          2              4      2012-08-26         3
# 1       2          4              5      2013-06-06         1
# 2       2          5              6      2013-12-23         6
# 3       3          3              3      2011-06-16         1
# 4       3          4              2      2011-05-26         1
# 5       3          4              7      2013-12-30         1
# 6       3          4             10      2016-05-08         4

# %%
pd.merge(user_products,transactions, on=['UserID','ProductID']).groupby(['UserID','ProductID'])

# %%
pd.merge(user_products,transactions, on=['UserID','ProductID']).groupby(['UserID','ProductID']).apply(lambda x:pd.Series(dict(Quantity=x.Quantity.sum())))
# Out:
#                   Quantity
# UserID ProductID
# 1      2                 3
# 2      4                 1
#        5                 6
# 3      3                 1
#        4                 6

# %%
pd.merge(user_products,transactions, on=['UserID','ProductID']).groupby(['UserID','ProductID']).apply(lambda x:pd.Series(dict(Quantity=x.Quantity.sum()))).reset_index().fillna(0)
# Out:
#    UserID  ProductID  Quantity
# 0       1          2         3
# 1       2          4         1
# 2       2          5         6
# 3       3          3         1
# 4       3          4         6

# %%
pd.merge(user_products,transactions, on=['UserID','ProductID']).groupby(['UserID','ProductID']).apply(lambda x:pd.Series(dict(Quantity=x.Quantity.sum()))).reset_index().fillna(0)
# Out:
#    UserID  ProductID  Quantity
# 0       1          2         3
# 1       2          4         1
# 2       2          5         6
# 3       3          3         1
# 4       3          4         6

# %%
print(transactions)
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1
# 5              6      2013-12-23     2.0          5         6
# 6              7      2013-12-30     3.0          4         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3
# 9             10      2016-05-08     3.0          4         4

# %%
pd.merge(transactions,transactions,on='UserID').head(5)
# Out:
#    TransactionID_x TransactionDate_x  UserID  ProductID_x  Quantity_x  \
# 0                1        2010-08-21     7.0            2           1
# 1                1        2010-08-21     7.0            2           1
# 2                9        2015-04-24     7.0            4           3
# 3                9        2015-04-24     7.0            4           3
# 4                2        2011-05-26     3.0            4           1
#
#    TransactionID_y TransactionDate_y  ProductID_y  Quantity_y
# 0                1        2010-08-21            2           1
# 1                9        2015-04-24            4           3
# 2                1        2010-08-21            2           1
# 3                9        2015-04-24            4           3
# 4                2        2011-05-26            4           1

# %%
pd.merge(transactions,transactions,on='UserID').first()

# %%
pd.merge(users,transactions.groupby('UserID').first().reset_index(),how='left',on='UserID')
# Out:
#    UserID      User  Gender Registered  Cancelled  TransactionID  \
# 0       1   Charles    male 2012-12-21        NaT            4.0
# 1       2     Pedro    male 2010-08-01 2010-08-08            5.0
# 2       3  Caroline  female 2012-10-23 2016-06-07            2.0
# 3       4   Brielle  female 2013-07-17        NaT            NaN
# 4       5  Benjamin    male 2010-11-25        NaT            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 2      2011-05-26        4.0       1.0
# 3             NaT        NaN       NaN
# 4             NaT        NaN       NaN

# %%
print(users)
transactions.groupby('UserID').first()
# Out:
#    UserID      User  Gender Registered  Cancelled
# 0       1   Charles    male 2012-12-21        NaT
# 1       2     Pedro    male 2010-08-01 2010-08-08
# 2       3  Caroline  female 2012-10-23 2016-06-07
# 3       4   Brielle  female 2013-07-17        NaT
# 4       5  Benjamin    male 2010-11-25        NaT
#         TransactionID TransactionDate  ProductID  Quantity
# UserID
# 1.0                 4      2012-08-26          2         3
# 2.0                 5      2013-06-06          4         1
# 3.0                 2      2011-05-26          4         1
# 7.0                 1      2010-08-21          2         1

# %%
transactions[transactions['UserID'] == 3.0]
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 6              7      2013-12-30     3.0          4         1
# 9             10      2016-05-08     3.0          4         4
